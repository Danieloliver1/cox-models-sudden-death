# %%
link = r'D:\cox-models-sudden-death\01_Dataset\dados_csv_info_definitions\subject-info_codes.csv'

# %%
import pandas as pd

df = pd.read_csv(link, sep=';', encoding='latin1')

# %%
df.head()
# Out:
#             Variable Column                         Notes  \
# 0  Exit of the study      D  Cause of exit from the study
# 1                NaN    NaN                           NaN
# 2                NaN    NaN                           NaN
# 3                NaN    NaN                           NaN
# 4                NaN    NaN                           NaN
#
#                                     Codes
# 0                           0: survivor;
# 1                 1: lost to follow-up;
# 2            2: cardiac transplantation;
# 3                              3: Death;
# 4  According to closing date of the study
