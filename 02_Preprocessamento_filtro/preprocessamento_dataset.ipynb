# %%
import pandas as pd
import glob
import os
import wfdb
# Define o padrão para os arquivos CSV

path = r'D:\cox-models-sudden-death\01_Dataset\dados_ECG\Holter_ECG\P0*'

#path = r'E:/Repositorio_Git/zzz-projeto_final/dados/ca-*.csv'


# Usando glob para pegar todos os arquivos que seguem o padrão
arquivos = glob.glob(path)
#arquivos_path_holter = glob.glob(path_holter)
arquivos = [os.path.splitext(arquivo)[0] for arquivo in arquivos] # tirando as a extensões





lista_sem_duplicatas = pd.Series(arquivos).unique().tolist() # removando duplicadas


record = wfdb.rdrecord(lista_sem_duplicatas[69])
record.__dict__
# Out:
# {'record_name': 'P0070',
#  'n_sig': 2,
#  'fs': 200,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 16476005,
#  'base_time': None,
#  'base_date': None,
#  'comments': [],
#  'sig_name': ['X', 'Y'],
#  'p_signal': array([[ 0.  ,  0.  ],
#         [ 0.  ,  0.  ],
#         [ 0.  ,  0.  ],
#         ...,
#         [ 0.3 ,  1.6 ],
#         [ 2.28,  1.58],
#         [ 0.36, -0.34]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['P0070.dat', 'P0070.dat'],
#  'fmt': ['16', '16'],
#  'samps_per_frame': [1, 1],
#  'skew': [None, None],
#  'byte_offset': [0, 0],
#  'adc_gain': [100.0, 100.0],
#  'baseline': [0, 0],
#  'units': ['mV', 'mV'],
#  'adc_res': [16, 16],
#  'adc_zero': [0, 0],
#  'init_value': [None, None],
#  'checksum': [None, None],
#  'block_size': [None, None]}

# %%
import pandas as pd

link_csv = r'D:\cox-models-sudden-death\01_Dataset\dados_csv_info_definitions\subject-info_formatado.csv'

df_info = pd.read_csv(link_csv, sep=';', header=0)

# %%
df_info
# Out:
#     Patient ID  Follow-up period from enrollment (days)  days_4years  \
# 0        P0001                                     2065         1460
# 1        P0002                                     2045         1460
# 2        P0003                                     2044         1460
# 3        P0004                                     2044         1460
# 4        P0005                                     2043         1460
# ..         ...                                      ...          ...
# 987      P1064                                     1393         1393
# 988      P1065                                     1393         1393
# 989      P1066                                     1387         1387
# 990      P1073                                     1365         1365
# 991      P1083                                     1624         1460
#
#      Exit of the study  Cause of death  SCD_4years SinusRhythm  \
# 0                  NaN               0                       0
# ...

# %%
link = r'D:\cox-models-sudden-death\02_Preprocessamento_filtro\resumo_dataset_ecg.csv'

df = pd.read_csv(link, sep=',')

# %%
df.head()
# Out:
#   paciente  n_canais  comprimento_sinal tem_X tem_Y tem_Z
# 0    P0001         3           16460600   Sim   Sim   Sim
# 1    P0002         3           16217800   Sim   Sim   Sim
# 2    P0003         3           15912600   Sim   Sim   Sim
# 3    P0004         3           15539200   Sim   Sim   Sim
# 4    P0005         3           15856000   Sim   Sim   Sim

# %%
# Filter patients where not all tem_X, tem_Y, tem_Z are "Sim"
df_lista = df[~((df['tem_X'] == 'Sim') & (df['tem_Y'] == 'Sim') & (df['tem_Z'] == 'Sim'))]

# %%
df_lista
# Out:
#     paciente  n_canais  comprimento_sinal tem_X tem_Y tem_Z
# 69     P0070         2           16476005   Sim   Sim   Não
# 121    P0125         2           12489750   Sim   Sim   Não
# 169    P0174         2           17278301   Sim   Sim   Não
# 238    P0247         2           17277894   Sim   Sim   Não
# 247    P0258         2           17277846   Sim   Sim   Não
# 290    P0302         2           17278079   Sim   Sim   Não
# 293    P0305         2           17277938   Sim   Sim   Não
# 297    P0310         2           17278846   Sim   Sim   Não
# 366    P0384         2           16765897   Sim   Sim   Não
# 398    P0421         2           17278035   Sim   Sim   Não
# 401    P0424         2           16634355   Sim   Sim   Não
# 402    P0425         2           14135384   Sim   Sim   Não
# 404    P0427         2           15830505   Sim   Sim   Não
# 416    P0448         2           17278273   Sim   Sim   Não
# 428    P0460         2           17277876   Sim   Sim   Não
# ...

# %%
lista = df_lista['paciente'].to_list()

# %%
lista
# Out:
# ['P0070',
#  'P0125',
#  'P0174',
#  'P0247',
#  'P0258',
#  'P0302',
#  'P0305',
#  'P0310',
#  'P0384',
#  'P0421',
#  'P0424',
#  'P0425',
#  'P0427',
#  'P0448',
#  'P0460',
#  'P0462',
#  'P0466',
#  'P0489',
#  'P0490',
#  'P0493',
#  'P0494',
#  'P0495',
#  'P0588',
#  'P0592',
#  'P0628',
#  'P0661',
#  'P0674',
#  'P0706',
#  'P0738',
#  'P0792',
#  'P0813',
#  'P0814',
#  'P0829',
#  'P0831',
#  'P0832',
#  'P0898',
#  'P0962',
#  'P1073']

# %%
# Reload df_info with correct separator and header


df_info[df_info['Patient ID'].isin(lista)]
# Out:
#     Patient ID  Follow-up period from enrollment (days)  days_4years  \
# 69       P0070                                      287          287
# 121      P0125                                     1966         1460
# 169      P0174                                     1960         1460
# 238      P0247                                     1949         1460
# 247      P0258                                     1945         1460
# 291      P0302                                     1919         1460
# 294      P0305                                     1919         1460
# 298      P0310                                     1919         1460
# 371      P0384                                     1940         1460
# 406      P0421                                     1880         1460
# 409      P0424                                     1889         1460
# 410      P0425                                     1889         1460
# 412      P0427                                     1882         1460
# ...

# %%
df_info[df_info['Patient ID'] == lista]
